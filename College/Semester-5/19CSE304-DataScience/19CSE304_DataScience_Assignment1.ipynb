# %% [markdown]
# <a href="https://colab.research.google.com/github/bsudharshan2001/MyRespository/blob/master/College/Semester-5/19CSE304-DataScience/19CSE304_DataScience_Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **19CSE304 - Foundations of Data Science - Assignment 1**
#
# ---

# %% [markdown]
# **B Sudharshan - CB.EN.U4CSE19008 - CSE A**

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv("/content/drive/MyDrive/SampleTransactionDetails.csv")
data
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333      NaN
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000      NaN
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333      NaN
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667      NaN
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
#
# [998 rows x 13 columns]

# %%
#Manipulation

# %%
data.fillna("Not Filled")
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude      US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940       64152
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000       97103
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500       35243
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060        8056
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890       61601
# ..                ...       ...    ...  ...        ...         ...         ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333  Not Filled
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000  Not Filled
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333  Not Filled
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667  Not Filled
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333  Not Filled
#
# [998 rows x 13 columns]

# %%
data.fillna(method='ffill')
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333  53715.0
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000  53715.0
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333  53715.0
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667  53715.0
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333  53715.0
#
# [998 rows x 13 columns]

# %%
data.fillna(method='bfill')
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333      NaN
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000      NaN
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333      NaN
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667      NaN
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
#
# [998 rows x 13 columns]

# %%
data.replace(to_replace=np.nan,value="Again Not Filled")
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude            US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940             64152
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000             97103
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500             35243
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060              8056
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890             61601
# ..                ...       ...    ...  ...        ...         ...               ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333  Again Not Filled
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000  Again Not Filled
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333  Again Not Filled
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667  Again Not Filled
# ...

# %%
data.dropna()
# Out:
#      Transaction_date   Product  Price  ...  Latitude  Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.19500  -94.68194  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.18806 -123.83000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.52056  -86.80250  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.79000  -75.23806   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.69361  -89.58889  61601.0
# ..                ...       ...    ...  ...       ...        ...      ...
# 458  01/23/2009 10:04  Product1   1200  ...  34.09833 -118.32583  90028.0
# 459  01/28/2009 11:19  Product1   1200  ...  39.65361 -105.19056  80465.0
# 460  01-07-2009 17:48  Product1   1200  ...  33.51722  -82.07583  30907.0
# 461  01-01-2009 04:24  Product3   7500  ...  42.94694  -76.42944  13152.0
# 462  01-12-2009 21:30  Product1   1200  ...  43.07306  -89.40111  53715.0
#
# [461 rows x 13 columns]

# %%
data.dropna(axis=1)
# Out:
#      Transaction_date   Product  Price  ...        Last_Login   Latitude   Longitude
# 0    01-02-2009 04:53  Product1   1200  ...  01-02-2009 07:49  39.195000  -94.681940
# 1    01-02-2009 13:08  Product1   1200  ...  01-03-2009 12:32  46.188060 -123.830000
# 2    01-04-2009 12:56  Product2   3600  ...  01-04-2009 12:45  33.520560  -86.802500
# 3    01-04-2009 13:19  Product1   1200  ...  01-04-2009 13:04  39.790000  -75.238060
# 4    01-04-2009 20:11  Product1   1200  ...  01-04-2009 19:45  40.693610  -89.588890
# ..                ...       ...    ...  ...               ...        ...         ...
# 993  01-02-2009 17:24  Product2   3600  ...   2/27/2009 18:43 -31.933333  115.833333
# 994  01-04-2009 18:57  Product1   1200  ...   2/28/2009 14:00 -28.050000  153.350000
# 995  01/23/2009 12:42  Product2   3600  ...   2/28/2009 22:26 -33.633333  151.333333
# 996  01-07-2009 19:48  Product2   3600  ...  03-01-2009 00:14 -33.883333  151.216667
# ...

# %%
data.dtypes
# Out:
# Transaction_date     object
# Product              object
# Price                 int64
# Payment_Type         object
# Name                 object
# City                 object
# State                object
# Country              object
# Account_Created      object
# Last_Login           object
# Latitude            float64
# Longitude           float64
# US Zip              float64
# dtype: object

# %%
data.iloc[250]
# Out:
# Transaction_date    01-08-2009 14:04
# Product                     Product1
# Price                           1200
# Payment_Type                    Amex
# Name                 AngelinaPatrick
# City                       San Diego
# State                             CA
# Country                United States
# Account_Created     01-07-2009 17:01
# Last_Login          02-03-2009 14:57
# Latitude                     32.7153
# Longitude                   -117.156
# US Zip                         92101
# Name: 250, dtype: object

# %%
data.iloc[-10]
# Out:
# Transaction_date    01/19/2009 01:52
# Product                     Product1
# Price                           1200
# Payment_Type                    Amex
# Name                         Kirsten
# City                       Melbourne
# State                       Victoria
# Country                    Australia
# Account_Created         4/24/07 4:36
# Last_Login           2/17/2009 01:20
# Latitude                    -37.8167
# Longitude                    144.967
# US Zip                           NaN
# Name: 988, dtype: object

# %%
data.iloc[10:20,]
# Out:
#     Transaction_date   Product  Price  ...  Latitude  Longitude   US Zip
# 10  01-02-2009 07:35  Product1   1200  ...  40.76083 -111.89028  84111.0
# 11  01-06-2009 07:18  Product1   1200  ...  32.64000 -117.08333  91910.0
# 12  01-01-2009 02:24  Product1   1200  ...  29.61944  -95.63472  77478.0
# 13  01-07-2009 08:08  Product1   1200  ...  40.71417  -74.00639  10007.0
# 14  01-01-2009 20:21  Product1   1200  ...  40.61278  -89.45917  61550.0
# 15  01-08-2009 00:42  Product1   1200  ...  37.22667 -121.97361  95032.0
# 16  01-08-2009 03:56  Product1   1200  ...  40.71417  -74.00639  10007.0
# 17  01-08-2009 03:16  Product1   1200  ...  25.77389  -80.19389  33130.0
# 18  01-03-2009 09:03  Product1   1200  ...  40.65000  -73.95000  11226.0
# 19  01-06-2009 07:46  Product1   1200  ...  38.96861  -77.34139  20190.0
#
# [10 rows x 13 columns]

# %%
data.iloc[:,10:21]
# Out:
#       Latitude   Longitude   US Zip
# 0    39.195000  -94.681940  64152.0
# 1    46.188060 -123.830000  97103.0
# 2    33.520560  -86.802500  35243.0
# 3    39.790000  -75.238060   8056.0
# 4    40.693610  -89.588890  61601.0
# ..         ...         ...      ...
# 993 -31.933333  115.833333      NaN
# 994 -28.050000  153.350000      NaN
# 995 -33.633333  151.333333      NaN
# 996 -33.883333  151.216667      NaN
# 997 -37.150000  -58.483333      NaN
#
# [998 rows x 3 columns]

# %%
data.iloc[[222,333,444,555],[3,4,5]]
# Out:
#     Payment_Type     Name            City
# 222       Diners  Heather        Ooltewah
# 333   Mastercard    Kelly  Hendersonville
# 444         Amex     John         Chicago
# 555         Visa  Allison       Edinburgh

# %%
data.loc[[222,333,444,555],['City','Price','Name']]
# Out:
#                City  Price     Name
# 222        Ooltewah   1200  Heather
# 333  Hendersonville   1200    Kelly
# 444         Chicago   3600     John
# 555       Edinburgh   1200  Allison

# %%
data.loc[data['Country']=='India','Product':'Country']
# Out:
#       Product  Price Payment_Type     Name       City           State Country
# 775  Product1   1200       Diners  barbara  Hyderabad  Andhra Pradesh   India
# 776  Product1   1200         Amex     Lisa    Gurgaon         Haryana   India

# %%
data['City']=data.apply(lambda x:x['Price']+200,axis=1)
data
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333      NaN
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000      NaN
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333      NaN
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667      NaN
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
#
# [998 rows x 13 columns]

# %% [markdown]
# GroupBy Commands

# %%
group1.get_group(2000)
# Out:
#      Transaction_date   Product  Price  ... Latitude Longitude   US Zip
# 261  01/23/2009 07:47  Product1   1800  ...  33.9525    -84.55  30060.0
#
# [1 rows x 12 columns]

# %%
group1=data.groupby('City')
group1.first()
# Out:
#        Transaction_date   Product  Price  ...  Latitude  Longitude   US Zip
# City                                      ...
# 450    01/30/2009 07:42  Product1    250  ...  34.18972 -118.13028  91001.0
# 1000   01/21/2009 11:28  Product1    800  ...  38.89028  -77.08444  22201.0
# 1400   01-02-2009 04:53  Product1   1200  ...  39.19500  -94.68194  64152.0
# 1450   01/26/2009 12:05  Product1   1250  ...  33.24861 -111.63361  85142.0
# 2000   01/23/2009 07:47  Product1   1800  ...  33.95250  -84.55000  30060.0
# 2300   01/16/2009 07:21  Product1   2100  ...  41.37222  -73.73389  10541.0
# 3800   01-04-2009 12:56  Product2   3600  ...  33.52056  -86.80250  35243.0
# 7700   01/20/2009 05:24  Product3   7500  ...  32.52500  -93.75000  71107.0
# 13200  01/28/2009 18:00  Product1  13000  ...  39.57917 -104.87639  80112.0
#
# [9 rows x 12 columns]

# %%
group1.get_group(1400)
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# 5    01-02-2009 20:09  Product1   1200  ...  36.343330  -88.850280  38237.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 990  01/20/2009 13:54  Product1   1200  ... -27.483333  153.216667      NaN
# 991  01/23/2009 21:35  Product1   1200  ... -27.500000  153.016667      NaN
# 992  01-06-2009 02:41  Product1   1200  ... -31.933333  115.833333      NaN
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000      NaN
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
#
# [841 rows x 12 columns]

# %%
group1.mean()
# Out:
#        Price   Latitude   Longitude        US Zip
# City
# 450      250  34.189720 -118.130280  91001.000000
# 1000     800  38.890280  -77.084440  22201.000000
# 1400    1200  39.276646  -41.570494  48668.670051
# 1450    1250  33.248610 -111.633610  85142.000000
# 2000    1800  33.952500  -84.550000  30060.000000
# 2300    2100  41.372220  -73.733890  10541.000000
# 3800    3600  38.385312  -36.551189  54966.181818
# 7700    7500  30.958611  -50.225925  60914.500000
# 13200  13000  39.579170 -104.876390  80112.000000

# %%
group1.describe()
# Out:
#        Price                         ...    US Zip
#        count     mean  std      min  ...       25%      50%       75%      max
# City                                 ...
# 450      1.0    250.0  NaN    250.0  ...  91001.00  91001.0  91001.00  91001.0
# 1000     1.0    800.0  NaN    800.0  ...  22201.00  22201.0  22201.00  22201.0
# 1400   841.0   1200.0  0.0   1200.0  ...  20169.25  39219.5  80118.25  99701.0
# 1450     1.0   1250.0  NaN   1250.0  ...  85142.00  85142.0  85142.00  85142.0
# 2000     1.0   1800.0  NaN   1800.0  ...  30060.00  30060.0  30060.00  30060.0
# 2300     1.0   2100.0  NaN   2100.0  ...  10541.00  10541.0  10541.00  10541.0
# 3800   136.0   3600.0  0.0   3600.0  ...  26063.50  55101.0  92602.00  99835.0
# 7700    15.0   7500.0  0.0   7500.0  ...  38466.00  71931.5  79188.25  92082.0
# 13200    1.0  13000.0  NaN  13000.0  ...  80112.00  80112.0  80112.00  80112.0
#
# [9 rows x 32 columns]

# %%
group1.dtypes
# Out:
#       Transaction_date Product  Price  ... Latitude Longitude   US Zip
# City                                   ...
# 450             object  object  int64  ...  float64   float64  float64
# 1000            object  object  int64  ...  float64   float64  float64
# 1400            object  object  int64  ...  float64   float64  float64
# 1450            object  object  int64  ...  float64   float64  float64
# 2000            object  object  int64  ...  float64   float64  float64
# 2300            object  object  int64  ...  float64   float64  float64
# 3800            object  object  int64  ...  float64   float64  float64
# 7700            object  object  int64  ...  float64   float64  float64
# 13200           object  object  int64  ...  float64   float64  float64
#
# [9 rows x 12 columns]

# %%
data.groupby("Product")["Name"].nunique()
# Out:
# Product
# Product1    645
# Product2    129
# Product3     15
# Name: Name, dtype: int64

# %%
data.groupby("City")["Name"].nunique()
# Out:
# City
# 450        1
# 1000       1
# 1400     639
# 1450       1
# 2000       1
# 2300       1
# 3800     129
# 7700      15
# 13200      1
# Name: Name, dtype: int64

# %% [markdown]
# Sorting Methods

# %%
data
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333      NaN
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000      NaN
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333      NaN
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667      NaN
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
#
# [998 rows x 13 columns]

# %%
data.sort_values("Price")
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 254  01/30/2009 07:42  Product1    250  ...  34.189720 -118.130280  91001.0
# 157  01/21/2009 11:28  Product1    800  ...  38.890280  -77.084440  22201.0
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 631  01/27/2009 09:01  Product1   1200  ...  41.383333    2.183333      NaN
# 632  01-12-2009 11:16  Product1   1200  ...  40.400000   -3.683333      NaN
# ..                ...       ...    ...  ...        ...         ...      ...
# 424  01/25/2009 11:35  Product3   7500  ...  29.538610  -95.447220  77545.0
# 938  01/14/2009 10:32  Product3   7500  ... -22.900000  -47.083333      NaN
# 100  01/20/2009 05:24  Product3   7500  ...  32.525000  -93.750000  71107.0
# 263  01-11-2009 04:29  Product3   7500  ...  35.960560  -83.920830  37902.0
# 294  01/28/2009 18:00  Product1  13000  ...  39.579170 -104.876390  80112.0
#
# [998 rows x 13 columns]

# %%
data.sort_index(inplace=True)
data
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333      NaN
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000      NaN
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333      NaN
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667      NaN
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
#
# [998 rows x 13 columns]

# %%
data.reindex()
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 0    01-02-2009 04:53  Product1   1200  ...  39.195000  -94.681940  64152.0
# 1    01-02-2009 13:08  Product1   1200  ...  46.188060 -123.830000  97103.0
# 2    01-04-2009 12:56  Product2   3600  ...  33.520560  -86.802500  35243.0
# 3    01-04-2009 13:19  Product1   1200  ...  39.790000  -75.238060   8056.0
# 4    01-04-2009 20:11  Product1   1200  ...  40.693610  -89.588890  61601.0
# ..                ...       ...    ...  ...        ...         ...      ...
# 993  01-02-2009 17:24  Product2   3600  ... -31.933333  115.833333      NaN
# 994  01-04-2009 18:57  Product1   1200  ... -28.050000  153.350000      NaN
# 995  01/23/2009 12:42  Product2   3600  ... -33.633333  151.333333      NaN
# 996  01-07-2009 19:48  Product2   3600  ... -33.883333  151.216667      NaN
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
#
# [998 rows x 13 columns]

# %%
data.sort_values(['Price'],ascending=[False])
# Out:
#      Transaction_date   Product  Price  ...   Latitude   Longitude   US Zip
# 294  01/28/2009 18:00  Product1  13000  ...  39.579170 -104.876390  80112.0
# 461  01-01-2009 04:24  Product3   7500  ...  42.946940  -76.429440  13152.0
# 424  01/25/2009 11:35  Product3   7500  ...  29.538610  -95.447220  77545.0
# 812  01-05-2009 02:57  Product3   7500  ...  48.083333   -1.683333      NaN
# 938  01/14/2009 10:32  Product3   7500  ... -22.900000  -47.083333      NaN
# ..                ...       ...    ...  ...        ...         ...      ...
# 364  01/29/2009 17:13  Product1   1200  ...  40.925280  -73.963330   7670.0
# 365  01/13/2009 09:16  Product1   1200  ...  36.165830  -86.784440  37219.0
# 997  01/25/2009 05:57  Product1   1200  ... -37.150000  -58.483333      NaN
# 157  01/21/2009 11:28  Product1    800  ...  38.890280  -77.084440  22201.0
# 254  01/30/2009 07:42  Product1    250  ...  34.189720 -118.130280  91001.0
#
# [998 rows x 13 columns]

# %% [markdown]
# Graphs and Plotting

# %%
import matplotlib.pyplot as pt
# %matplotlib inline
pt.style.use('ggplot')
plt.figure(figsize=(15,15))
x=data['Price'][100:150]
y=data['Longitude'][100:150]
pt.plot(x,y)
pt.xlabel('Price')
pt.ylabel('Longitude')
pt.show()

# %%
data.plot.scatter(x='Latitude',y='Longitude',figsize=(15,15))

# %%
data.plot.scatter(x='Price',y='Longitude',figsize=(15,15))

# %%
data.plot.scatter(x='Price',y='Latitude',figsize=(15,15))
