# %% [markdown]
# <a href="https://colab.research.google.com/github/bsudharshan2001/MyRespository/blob/master/College/Semester-5/19CSE305-MachineLearning/Lab-7/CB.EN.U4CSE19008_EX1_Building_Linear_Regression_from_scratch_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# B Sudharshan - CB.EN.U4CSE19008 - CSE A
# ---
# -----------------------------

# %% [markdown]
# #  19CSE305:Machine Learning
#
# ## Linear Regression:Gradient Descent

# %% [markdown]
# Linear Regression:
#
# **Y = wX + b**
#
# Y --> Dependent Variable
#
# X --> Independent Variable
#
# w --> weight
#
# b --> bias

# %% [markdown]
# **Gradient Descent:**
#
# Gradient Descent is an optimization algorithm used for minimizing the loss function in various machine learning algorithms. It is used for updating the parameters of the learning model.
#
# w  =  w - α*dw
#
# b  =  b - α*db

# %% [markdown]
# **Learning Rate:**
#
# Learning rate is a tuning parameter in an optimization algorithm that determines the step size at each iteration while moving toward a minimum of a loss function.

# %% [markdown]
# ![dw.png](data:image/png;base64,...)

# %% [markdown]
# ![db.png](data:image/png;base64,...)

# %%
# Making the imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

# Preprocessing Input data
data = pd.read_csv('/content/data.csv')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]
plt.scatter(X, Y)
plt.show()

# %%
# Building the model
m = 0
c = 0

L = 0.0001  # The learning Rate
epochs = 300000  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + c  # The current predicted value of Y
    D_m = (-2/n) * sum(X * (Y - Y_pred))  # Derivative wrt m
    D_c = (-2/n) * sum(Y - Y_pred)  # Derivative wrt c
    m = m - L * D_m  # Update m
    c = c - L * D_c  # Update c
    
print (m, c)
# Out:
# 1.3086537317574174 8.822464803204838

# %% [markdown]
# **Linear Regression**

# %%
# Making predictions
Y_pred = m*X + c

plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red') # predicted
plt.show()

# %% [markdown]
# ## **Linear Regression using SKLEARN**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('/content/data.csv')
X = data.iloc[:, 0].values.reshape(-1, 1) # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1) # -1 means that calculate the dimension of rows, but have 1 column
LR = LinearRegression()
LR.fit(X, Y)
Y_pred =LR.predict(X)

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
print(LR.intercept_) # Yintercept
print(LR.coef_) #Slope
# Out:
# [9.90860619]
# [[1.28735737]]

# %% [markdown]
# # **Excercise 1**
# Download the dataset from the following link:
# https://drive.google.com/open?id=1oakZCv7g3mlmCSdv9J8kdSaqO5_6dIOw

# %%
# Displya first 5 records from the dataset
data=pd.read_csv("/content/student_scores.csv")
data.head(5)
#Display the statistical details of the dataset
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
#Split the independent and dependent variables and plot the data
ind_x=data['Hours']
dep_y=data['Scores']

# %% [markdown]
# Explore  Scikit-Learn's built-in [train_test_split() ](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) method

# %%
#Split the data into train and test set :  80% of the data to training set and 20% data to test set
from sklearn.model_selection import train_test_split
indx_train,indx_test,depy_train,depy_test=train_test_split(ind_x,dep_y,test_size=0.2)

# %%
#Train an linear regression model and display the parameters (m,c)
m=0
c=0
L=0.0001
epochs=1000
n=float(len(ind_x))
for i in range(epochs):
  y_pred=m*ind_x+c
  d_m=(-2/n) * sum(ind_x * (dep_y - y_pred))  
  d_c = (-2/n) * sum(dep_y - y_pred) 
  m = m - L * d_m  
  c = c - L * d_c 
print(m,c)
# Out:
# 9.896964110671043 1.6314708810783134

# %% [markdown]
# Explore sk learn predict method

# %%
#Make predictions for the test data
x=data.iloc[:,0].values.reshape(-1, 1)
y=data.iloc[:,1].values.reshape(-1, 1)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
linear=LinearRegression()
linear.fit(x,y)
y_pred=linear.predict(x)

# %%
#Display actual and predicted vlues
print("Actual Values : ",y)
print("Predicted Values : ",y_pred)
# Out:
# Actual Values :  [[21]
#  [47]
#  [27]
#  [75]
#  [30]
#  [20]
#  [88]
#  [60]
#  [81]
#  [25]
#  [85]
#  [62]
#  [41]
#  [42]
#  [17]
#  [95]
#  [30]
#  [24]
#  [67]
#  [69]
#  [30]
#  [54]
#  [35]
#  [76]
#  [86]]
# Predicted Values :  [[26.92318188]
#  [52.3402707 ]
#  [33.76624426]
#  [85.57800223]
#  [36.69898527]
#  [17.14737849]
#  [92.4210646 ]
#  [56.25059205]
#  [83.62284155]
#  [28.87834256]
#  [77.75735951]
#  [60.16091341]
#  [46.47478866]
#  [34.74382459]
#  [13.23705714]
#  [89.48832358]
#  [26.92318188]
#  [21.05769985]
#  [62.11607409]
#  [74.8246185 ]
#  [28.87834256]
#  [49.40752968]
#  [39.63172629]
#  [69.9367168 ]
#  [78.73493985]]
