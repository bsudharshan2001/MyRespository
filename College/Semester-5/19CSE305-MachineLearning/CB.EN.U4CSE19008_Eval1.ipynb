# %% [markdown]
# <a href="https://colab.research.google.com/github/bsudharshan2001/MyRespository/blob/master/College/Semester-5/19CSE305-MachineLearning/CB.EN.U4CSE19008_Eval1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 19CSE305 - Machine Learning - Evaluation 1
# ---
# -------------------------
# B Sudharshan - CB.EN.U4CSE19008 - CSE A

# %% [markdown]
# (1) Loading the data set

# %%
#1(a)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
#1(b)
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
tmdb=pd.read_csv('/content/drive/MyDrive/tmdb_movies_data.csv')
tmdb
# Out:
#            id    imdb_id  popularity  ...  release_year    budget_adj   revenue_adj
# 0      135397  tt0369610   32.985763  ...          2015  1.379999e+08  1.392446e+09
# 1       76341  tt1392190   28.419936  ...          2015  1.379999e+08  3.481613e+08
# 2      262500  tt2908446   13.112507  ...          2015  1.012000e+08  2.716190e+08
# 3      140607  tt2488496   11.173104  ...          2015  1.839999e+08  1.902723e+09
# 4      168259  tt2820852    9.335014  ...          2015  1.747999e+08  1.385749e+09
# ...       ...        ...         ...  ...           ...           ...           ...
# 10861      21  tt0060371    0.080598  ...          1966  0.000000e+00  0.000000e+00
# 10862   20379  tt0060472    0.065543  ...          1966  0.000000e+00  0.000000e+00
# 10863   39768  tt0060161    0.065141  ...          1966  0.000000e+00  0.000000e+00
# 10864   21449  tt0061177    0.064317  ...          1966  0.000000e+00  0.000000e+00
# ...

# %%
#1(c)
tmdb[['genere1','genere2','genere3']] = tmdb.genres.str.split(expand=True)
tmdb.head()
# Out:
#        id    imdb_id  ...           genere2  genere3
# 0  135397  tt0369610  ...  Fiction|Thriller     None
# 1   76341  tt1392190  ...  Fiction|Thriller     None
# 2  262500  tt2908446  ...  Fiction|Thriller     None
# 3  140607  tt2488496  ...   Fiction|Fantasy     None
# 4  168259  tt2820852  ...              None     None
#
# [5 rows x 24 columns]

# %%
#1(c)
tmdb.describe()
# Out:
#                   id    popularity  ...    budget_adj   revenue_adj
# count   10866.000000  10866.000000  ...  1.086600e+04  1.086600e+04
# mean    66064.177434      0.646441  ...  1.755104e+07  5.136436e+07
# std     92130.136561      1.000185  ...  3.430616e+07  1.446325e+08
# min         5.000000      0.000065  ...  0.000000e+00  0.000000e+00
# 25%     10596.250000      0.207583  ...  0.000000e+00  0.000000e+00
# 50%     20669.000000      0.383856  ...  0.000000e+00  0.000000e+00
# 75%     75610.000000      0.713817  ...  2.085325e+07  3.369710e+07
# max    417859.000000     32.985763  ...  4.250000e+08  2.827124e+09
#
# [8 rows x 10 columns]

# %% [markdown]
# 2. Basic operations with dataframe

# %%
#2(a)
tmdb.head(5)
# Out:
#        id    imdb_id  ...           genere2  genere3
# 0  135397  tt0369610  ...  Fiction|Thriller     None
# 1   76341  tt1392190  ...  Fiction|Thriller     None
# 2  262500  tt2908446  ...  Fiction|Thriller     None
# 3  140607  tt2488496  ...   Fiction|Fantasy     None
# 4  168259  tt2820852  ...              None     None
#
# [5 rows x 24 columns]

# %%
tmdb.tail(5)
# Out:
#           id    imdb_id  popularity  ...                 genere1  genere2 genere3
# 10861     21  tt0060371    0.080598  ...             Documentary     None    None
# 10862  20379  tt0060472    0.065543  ...  Action|Adventure|Drama     None    None
# 10863  39768  tt0060161    0.065141  ...          Mystery|Comedy     None    None
# 10864  21449  tt0061177    0.064317  ...           Action|Comedy     None    None
# 10865  22293  tt0060666    0.035919  ...                  Horror     None    None
#
# [5 rows x 24 columns]

# %%
tmdb.sample(n=5)
# Out:
#           id    imdb_id  ...  genere2  genere3
# 2900   12162  tt0887912  ...     None     None
# 2433    9481  tt0145681  ...     None     None
# 5964  214100  tt2481198  ...     None     None
# 9680   20465  tt0092576  ...     None     None
# 9528   29095  tt0096426  ...     None     None
#
# [5 rows x 24 columns]

# %%
#2(b)
tmdb.dtypes
# Out:
# id                        int64
# imdb_id                  object
# popularity              float64
# budget                    int64
# revenue                   int64
# original_title           object
# cast                     object
# homepage                 object
# director                 object
# tagline                  object
# keywords                 object
# overview                 object
# runtime                   int64
# genres                   object
# production_companies     object
# release_date             object
# vote_count                int64
# vote_average            float64
# release_year              int64
# budget_adj              float64
# revenue_adj             float64
# genere1                  object
# genere2                  object
# genere3                  object
# dtype: object

# %%
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %%
#2(b)
tmdb=tmdb.drop(['keywords', 'overview'], axis = 1)
tmdb.head(1)
# Out:
#        id    imdb_id  ...           genere2  genere3
# 0  135397  tt0369610  ...  Fiction|Thriller     None
#
# [1 rows x 22 columns]

# %% [markdown]
# 3. Row and Column processing of dataframe

# %%
#3(a)
tmdb.iloc[25,-6:]
# Out:
# release_year           2015
# budget_adj         1.38e+08
# revenue_adj     6.27743e+08
# genere1              Action
# genere2                None
# genere3                None
# Name: 25, dtype: object

# %%
#3(b)
tmdb[tmdb.genres.isnull()]
# Out:
#            id    imdb_id  popularity  ...  genere1  genere2 genere3
# 424    363869  tt4835298    0.244648  ...      NaN      NaN     NaN
# 620    361043  tt5022680    0.129696  ...      NaN      NaN     NaN
# 997    287663        NaN    0.330431  ...      NaN      NaN     NaN
# 1712    21634  tt1073510    0.302095  ...      NaN      NaN     NaN
# 1897    40534  tt1229827    0.020701  ...      NaN      NaN     NaN
# 2370   127717  tt1525359    0.081892  ...      NaN      NaN     NaN
# 2376   315620  tt1672218    0.068411  ...      NaN      NaN     NaN
# 2853    57892  tt0270053    0.130018  ...      NaN      NaN     NaN
# 3279    54330  tt1720044    0.145331  ...      NaN      NaN     NaN
# 4547   123024  tt2305700    0.520520  ...      NaN      NaN     NaN
# 4732   139463  tt2084977    0.235911  ...      NaN      NaN     NaN
# 4797   369145        NaN    0.167501  ...      NaN      NaN     NaN
# 4890   126909  tt2219564    0.083202  ...      NaN      NaN     NaN
# ...

# %%
tmdb[tmdb.genres.isnull()].count()
# Out:
# id                      0
# imdb_id                 0
# popularity              0
# budget                  0
# revenue                 0
# original_title          0
# cast                    0
# director                0
# tagline                 0
# runtime                 0
# genres                  0
# production_companies    0
# release_date            0
# vote_count              0
# vote_average            0
# release_year            0
# budget_adj              0
# revenue_adj             0
# genere1                 0
# dtype: int64

# %%
tmdb=tmdb[tmdb['genres'].notna()]

# %% [markdown]
# 4. Handling Missing Values

# %%
#4(a)
tmdb.isnull().sum()
# Out:
# id                          0
# imdb_id                     8
# popularity                  0
# budget                      0
# revenue                     0
# original_title              0
# cast                       75
# homepage                 7912
# director                   42
# tagline                  2806
# runtime                     0
# genres                      0
# production_companies     1016
# release_date                0
# vote_count                  0
# vote_average                0
# release_year                0
# budget_adj                  0
# revenue_adj                 0
# genere1                     0
# genere2                  9465
# genere3                 10824
# dtype: int64

# %%
fif=tmdb.shape[0]/2
tmdb=tmdb.loc[:,(tmdb.isnull().sum(axis=0) <= fif)]

# %%
tmdb.isnull().sum()
# Out:
# id                         0
# imdb_id                    8
# popularity                 0
# budget                     0
# revenue                    0
# original_title             0
# cast                      75
# director                  42
# tagline                 2806
# runtime                    0
# genres                     0
# production_companies    1016
# release_date               0
# vote_count                 0
# vote_average               0
# release_year               0
# budget_adj                 0
# revenue_adj                0
# genere1                    0
# dtype: int64

# %%
#4(b)
tmdb.replace(0,np.nan)
# Out:
#            id    imdb_id  ...   revenue_adj                   genere1
# 0      135397  tt0369610  ...  1.392446e+09  Action|Adventure|Science
# 1       76341  tt1392190  ...  3.481613e+08  Action|Adventure|Science
# 2      262500  tt2908446  ...  2.716190e+08         Adventure|Science
# 3      140607  tt2488496  ...  1.902723e+09  Action|Adventure|Science
# 4      168259  tt2820852  ...  1.385749e+09     Action|Crime|Thriller
# ...       ...        ...  ...           ...                       ...
# 10861      21  tt0060371  ...           NaN               Documentary
# 10862   20379  tt0060472  ...           NaN    Action|Adventure|Drama
# 10863   39768  tt0060161  ...           NaN            Mystery|Comedy
# 10864   21449  tt0061177  ...           NaN             Action|Comedy
# 10865   22293  tt0060666  ...           NaN                    Horror
#
# [10843 rows x 19 columns]

# %%
#4(c)
tmdb.replace(np.nan,tmdb.mean(),inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
tmdb
# Out:
#            id    imdb_id  ...   revenue_adj                   genere1
# 0      135397  tt0369610  ...  1.392446e+09  Action|Adventure|Science
# 1       76341  tt1392190  ...  3.481613e+08  Action|Adventure|Science
# 2      262500  tt2908446  ...  2.716190e+08         Adventure|Science
# 3      140607  tt2488496  ...  1.902723e+09  Action|Adventure|Science
# 4      168259  tt2820852  ...  1.385749e+09     Action|Crime|Thriller
# ...       ...        ...  ...           ...                       ...
# 10861      21  tt0060371  ...  0.000000e+00               Documentary
# 10862   20379  tt0060472  ...  0.000000e+00    Action|Adventure|Drama
# 10863   39768  tt0060161  ...  0.000000e+00            Mystery|Comedy
# 10864   21449  tt0061177  ...  0.000000e+00             Action|Comedy
# 10865   22293  tt0060666  ...  0.000000e+00                    Horror
#
# [10843 rows x 19 columns]

# %% [markdown]
# 5. Data Visualization

# %%
#5a
tmdb['popularity'].plot(kind="bar", title="Movie Popularity")
plt.title("Movie Populareach year")
plt.xlabel("Popularity")
plt.ylabel("Original Title")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-98-e6747575d4d2> in <module>()
#       1 #5a
# ----> 2 tmdb['popularity'].plot(kind="bar", title="Movie Popularity")
#       3 plt.title("Movie Populareach year")
#       4 plt.xlabel("Popularity")
#       5 plt.ylabel("Original Title")
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     947                     data.columns = label_name
#     948
# --> 949         return plot_backend.plot(data, kind=kind, **kwargs)
#     950
#     951     __call__.__doc__ = __doc__
#
# /usr/local/lib/python3.7/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
# ...

# %% [markdown]
# 6.	Encoding

# %%
#6(a)
label_enc=LabelEncoder()
label = label_enc.fit_transform(tmdb.genres)
tmdb["genres"]=label
label_enc = LabelEncoder()
label =label_enc.fit_transform(tmdb.release_year)
tmdb["release_year"]=label
tmdb
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            id    imdb_id  ...   revenue_adj                   genere1
# 0      135397  tt0369610  ...  1.392446e+09  Action|Adventure|Science
# ...

# %% [markdown]
# 7. Train - Test Split

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
train_tmdb, test_tmdb = train_test_split(tmdb,shuffle=False,test_size=0.2)
